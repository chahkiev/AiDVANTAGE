# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import datetime

df = pd.read_csv('post_dataframe.csv', index_col='Unnamed: 0')

df_x = df['4.Болели ли Ваши кровные родственники злокачественными опухолевыми заболеваниями? ']
df_y = df['6.Вы курите?']
df_z = df['Диагноз']

fig = go.Figure(data=go.Heatmap(x=df_x.values, y=df_y.values, z=df_z.values))
# fig.show()

fig.update_layout(
    autosize=False,
    width=500,
    height=500,
    xaxis=go.layout.XAxis(
        title_text = df_x.name,
        ticktext=["Нет", "Да", "Не знаю"],
        tickvals=[0, 1, 2],
        tickmode="array",
        titlefont=dict(size=10),
    ),
    yaxis=go.layout.YAxis(
        title_text=df_y.name,
        ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет"],
        tickvals=[0, 1, 2],
        tickmode="array",
        titlefont=dict(size=10),
    )
)
fig.show()

# %%
df_x = df['14.Была ли уВас  рвота после еды?  ']
df_y = df['6.Вы курите?']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Нет", "Да, дольше 1 месяца, стабильно", "Да, иногда, около месяца"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1166bd7e3a3> in <module>
# ----> 1 df_x = df['14.Была ли уВас  рвота после еды?  ']
#       2 df_y = df['6.Вы курите?']
#       3 df_z = df['Диагноз']
#       4
#       5 N = 50
#
# NameError: name 'df' is not defined

# %%
df_x = df['13.Когда-либо Вам был установлен диагноз: язва (или полип) желудка? ']
df_y = df['3.Работали ли Вы на предприятиях с повышенной вредностью ( горячий цех, химическое производство, с продуктами нефтепереработки, и т.д)']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Нет", "Да", "Не помню"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Есть или были в прошлом", "Да, есть или были в прошлом"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['7.Какое количество сигарет в день Вы выкуриваете?']
df_y = df['3.Работали ли Вы на предприятиях с повышенной вредностью ( горячий цех, химическое производство, с продуктами нефтепереработки, и т.д)']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Не курю", "Больше пачки", "Меньше пачки"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Есть или были в прошлом", "Да, есть или были в прошлом"],
                        tickvals=[0, 1],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['9. Являетесь ли Вы пассивным курильщиком ? (наличие активного курильщика дома, на работе?)']
df_y = df['24.Заметили ли Вы, что похудели за последние 3 месяца больше чем на 5 кг ненамеренно? ']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Нет", "Да"],
                         tickvals=[0, 1],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Да, существенно","Не знаю"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['2.Подвергались ли Вы воздействию вредных условий (различные виды излучения, вредное производство,  токсичные вещества)']
df_y = df['14.Была ли уВас  рвота после еды?  ']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Нет", "Да"],
                         tickvals=[0, 1],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Да, дольше 1 месяца, стабильно", "Да, иногда, около месяца"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['11.Замечали ли Вы изменение тембра голоса (осиплость, хрипоту)?']
df_y = df['12.Был ли у Вас дискомфорт во время глотания пищи или воды ( застревание, ощущение инородного тела в горле или пищеводе)?']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Нет", "Да, иногда  в течение последнего месяца", "Да, постоянно, дольше 1 месяца"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=[ "Нет", "Иногда, около месяца","Да, дольше 1 месяца, стабильно"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['6.Вы курите?']
df_y = df['3.Работали ли Вы на предприятиях с повышенной вредностью ( горячий цех, химическое производство, с продуктами нефтепереработки, и т.д)']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text="Работали ли Вы на предприятиях с повышенной вредностью",
                         ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Есть или были в прошлом","Да, есть или были в прошлом"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['7.Какое количество сигарет в день Вы выкуриваете?']
df_y = df['3.Работали ли Вы на предприятиях с повышенной вредностью ( горячий цех, химическое производство, с продуктами нефтепереработки, и т.д)']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,
                         ticktext=["Не курю", "Больше пачки" , "Меньше пачки"],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Есть или были в прошлом", "Да, есть или были в прошлом"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['9. Являетесь ли Вы пассивным курильщиком ? (наличие активного курильщика дома, на работе?)']
df_y = df['3.Работали ли Вы на предприятиях с повышенной вредностью ( горячий цех, химическое производство, с продуктами нефтепереработки, и т.д)']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,                  //////////  
                         ticktext=["Нет", "Да" ],
                         tickvals=[0, 1],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Есть или были в прошлом", "Да, есть или были в прошлом"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['14.Была ли уВас  рвота после еды?  ']
df_y = df['6.Вы курите?']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text="Была ли у вас рвота",
                         ticktext=["Нет", "Да, дольше 1 месяца, стабильно", "Да, иногда, около месяца" ],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text="Вы курите?",
                        ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['6.Вы курите?']
df_y = df['15.Находили ли у Вас ранее заболевание толстого кишечника? ']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,                   
                         ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет" ],
                         tickvals=[0, 1, 2],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Да, полипы толстой кишки", "Да, геморрой", "Да, трещину заднего прохода"],
                        tickvals=[0, 1, 2, 3],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['6.Вы курите?']
df_y = df['25.Находили ли Вы у себя увеличенные лимфоузлы ? ']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text=df_x.name,                   
                         ticktext=["Нет, никогда не курил", "Да, больше 10 лет", "Да, меньше 10 лет" ],
                         tickvals=[0, 2, 1],
                         titlefont=dict(size=10),
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text=df_y.name,
                        ticktext=["Нет", "Да"],
                        tickvals=[0, 1],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=10),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()

# %%
df_x = df['23.Есть ли у Вас боли, требующие систематического приема анальгетиков? ']
df_y = df['11.Замечали ли Вы изменение тембра голоса (осиплость, хрипоту)?']
df_z = df['Диагноз']

N = 50
fig = go.Figure(data=[go.Mesh3d(x=df_x.values,
                   y=df_y.values,
                   z=df_z.values,
                   opacity=0.5,)])


# xaxis.backgroundcolor is used to set background color
fig.update_layout(scene = dict(
                    xaxis = dict(
                         title_text="Есть ли у Вас боли, требующие систематического приема анальгетиков?",                   
                         ticktext=["Нет", "Да"],
                         tickvals=[0, 1],
                         titlefont=dict(size=15),   ### Размер title_text
                         tickmode="array",
                         backgroundcolor="rgb(200, 200, 230)",
                         gridcolor="white",
                         showbackground=True,
                         zerolinecolor="white",),
                    yaxis = dict(
                        title_text="Замечали ли Вы изменение тембра голоса",  
                        ticktext=["Нет", "Да, иногда  в течение последнего месяца","Да, постоянно, дольше 1 месяца"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=15),   ### Размер title_text
                        tickmode="array",
                        backgroundcolor="rgb(230, 200,230)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white"),
                    zaxis = dict(
                        title_text=df_z.name,
                        ticktext=["Низкая вероятность", "Среднее", "Высокая"],
                        tickvals=[0, 1, 2],
                        titlefont=dict(size=15),
                        tickmode="array",
                        backgroundcolor="rgb(230, 230,200)",
                        gridcolor="white",
                        showbackground=True,
                        zerolinecolor="white",),),
                    width=700,
                    margin=dict(
                    r=10, l=10,
                    b=10, t=10)
                  )
fig.show()
